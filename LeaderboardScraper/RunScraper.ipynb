# %% [markdown]
# # Leaderboard Scraper

# %% [markdown]
# ### Run the Scraper
# <span style="color:red">Note: If you see a "ReactorNotRestartable" error, press the refresh button to restart the Kernel.</span>

# %%
import scrapy
from twisted.internet import reactor, defer
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging
from scrapy.utils.project import get_project_settings
import os
from os import listdir
from os.path import isfile, join
import time 

CURRENT_WORKING_DIR = os.path.abspath(os.getcwd())
INPUT_DIRECTORY = 'AddLeaderboardFiles'
FULL_INPUT_DIRECTORY_PATH = '{}/{}'.format(CURRENT_WORKING_DIR, INPUT_DIRECTORY)

settings = get_project_settings()
configure_logging(settings)
runner = CrawlerRunner(settings)

@defer.inlineCallbacks
def scrape_files():
    files = [f for f in listdir(FULL_INPUT_DIRECTORY_PATH) if isfile(join(FULL_INPUT_DIRECTORY_PATH, f))]
    if len(files) == 0:
        reactor.stop()
    else:
        file_to_scrape = "file://{}/{}".format(FULL_INPUT_DIRECTORY_PATH, files[0])
        print(file_to_scrape)
        yield runner.crawl('leaderboard', file_name=file_to_scrape)
        scrape_files()


files = [f for f in listdir(FULL_INPUT_DIRECTORY_PATH) if isfile(join(FULL_INPUT_DIRECTORY_PATH, f))]
if len(files) == 0:
    print("OOPS! You need to add files to scrape.")
else:
    scrape_files()
    reactor.run()
    print("\nSUCCESS! Scraping finished. :)")
# Out:
# 2023-01-22 15:29:08 [scrapy.crawler] INFO: Overridden settings:
# {'AUTOTHROTTLE_ENABLED': True,
#  'BOT_NAME': 'tourneys',
#  'CONCURRENT_REQUESTS': 32,
#  'CONCURRENT_REQUESTS_PER_DOMAIN': 32,
#  'DOWNLOAD_TIMEOUT': 600,
#  'NEWSPIDER_MODULE': 'tourneys.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'SPIDER_MODULES': ['tourneys.spiders']}
# 2023-01-22 15:29:08 [scrapy.extensions.telnet] INFO: Telnet Password: b8ab1440b574013c
# 2023-01-22 15:29:08 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.throttle.AutoThrottle']
# file:///Users/claytonwinterbotham/code/python/notebooks/HorseRankerNotebooks/LeaderboardScraper/AddLeaderboardFiles/Leaderboards - HorseTourneys.com.html
# --------------------------------------------
# 2023-01-22 15:29:08 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-01-22 15:29:08 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-01-22 15:29:08 [scrapy.middleware] INFO: Enabled item pipelines:
# ['tourneys.pipelines.PostgresPipeline']
# 2023-01-22 15:29:08 [scrapy.core.engine] INFO: Spider opened
# 2023-01-22 15:29:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-01-22 15:29:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-01-22 15:29:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET file:///Users/claytonwinterbotham/code/python/notebooks/HorseRankerNotebooks/LeaderboardScraper/AddLeaderboardFiles/Leaderboards%20-%20HorseTourneys.com.html> (referer: None)
# 2023-01-22 15:29:09 [scrapy.core.scraper] DEBUG: Scraped from <200 file:///Users/claytonwinterbotham/code/python/notebooks/HorseRankerNotebooks/LeaderboardScraper/AddLeaderboardFiles/Leaderboards%20-%20HorseTourneys.com.html>
# {'contest_code': '1405204',
#  'date': '2023-01-22',
#  'name': 'GOLDEN GATE - $100 WINNER TAKE ALL - Runs w/ 3 - Cap $100 - P&P',
#  'players': [{'earnings': 21.8,
#               'entry': 1,
#               'name': 'Rich Constantine',
#               'rank': 1},
#              {'earnings': 16.8,
#               'entry': 1,
#               'name': 'Michael Alfano',
#               'rank': 2},
#              {'earnings': 10.8, 'entry': 1, 'name': 'Greg Altieri', 'rank': 3}],
#  'races': [{'race_number': '2', 'track_abbr': 'GG'},
#            {'race_number': '3', 'track_abbr': 'GG'},
#            {'race_number': '4', 'track_abbr': 'GG'},
#            {'race_number': '5', 'track_abbr': 'GG'},
#            {'race_number': '6', 'track_abbr': 'GG'},
#            {'race_number': '7', 'track_abbr': 'GG'},
#            {'race_number': '8', 'track_abbr': 'GG'},
#            {'race_number': '9', 'track_abbr': 'GG'}],
#  'results': [{'horse_name': "J T's Creditcard",
#               'horse_number': '2',
#               'place': 5.2,
#               'race_number': '2',
#               'show': 2.6,
#               'track_name': 'Golden Gate Fields',
#               'win': 8.4},
#              {'horse_name': 'Talisker Bay',
#               'horse_number': '4',
#               'place': 5.0,
#               'race_number': '2',
#               'show': 2.4,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Macho Chrome',
#               'horse_number': '1',
#               'place': 0.0,
#               'race_number': '2',
#               'show': 2.1,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Polacco',
#               'horse_number': '1',
#               'place': 2.6,
#               'race_number': '3',
#               'show': 2.2,
#               'track_name': 'Golden Gate Fields',
#               'win': 4.4},
#              {'horse_name': 'Harbor Sky',
#               'horse_number': '2',
#               'place': 3.4,
#               'race_number': '3',
#               'show': 2.6,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Mr Botanicals',
#               'horse_number': '3',
#               'place': 0.0,
#               'race_number': '3',
#               'show': 2.8,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Class Code',
#               'horse_number': '2',
#               'place': 4.6,
#               'race_number': '4',
#               'show': 2.6,
#               'track_name': 'Golden Gate Fields',
#               'win': 9.4},
#              {'horse_name': 'Last Inning',
#               'horse_number': '4',
#               'place': 10.4,
#               'race_number': '4',
#               'show': 4.8,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Dance Lady',
#               'horse_number': '6',
#               'place': 0.0,
#               'race_number': '4',
#               'show': 2.2,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': 'Talk About Autism',
#               'horse_number': '2',
#               'place': 3.0,
#               'race_number': '5',
#               'show': 2.4,
#               'track_name': 'Golden Gate Fields',
#               'win': 7.8},
#              {'horse_name': 'Captivating Boy',
#               'horse_number': '6',
#               'place': 2.8,
#               'race_number': '5',
#               'show': 2.2,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0},
#              {'horse_name': "Piper's Causeway",
#               'horse_number': '5',
#               'place': 0.0,
#               'race_number': '5',
#               'show': 2.4,
#               'track_name': 'Golden Gate Fields',
#               'win': 0.0}],
#  'selections': [{'horse_name': 'Talisker Bay',
#                  'horse_number': '4',
#                  'place': 5.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '2',
#                  'selection_number': 1,
#                  'show': 5.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Runaway Kristin',
#                  'horse_number': '4',
#                  'place': 0.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '3',
#                  'selection_number': 2,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Class Code',
#                  'horse_number': '2',
#                  'place': 4.6,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '4',
#                  'selection_number': 3,
#                  'show': 14.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 9.4},
#                 {'horse_name': 'Captivating Boy',
#                  'horse_number': '6',
#                  'place': 2.8,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '5',
#                  'selection_number': 4,
#                  'show': 2.8,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Irish Song Leader',
#                  'horse_number': '7',
#                  'place': 0.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '6',
#                  'selection_number': 5,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Our Expectation',
#                  'horse_number': '8',
#                  'place': 0.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '7',
#                  'selection_number': 6,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Stoic Luna',
#                  'horse_number': '1',
#                  'place': 0.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '8',
#                  'selection_number': 7,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Lil Miracle Man',
#                  'horse_number': '7',
#                  'place': 0.0,
#                  'player': 'Rich Constantine',
#                  'player_entry': 1,
#                  'race_number': '9',
#                  'selection_number': 8,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Sky Dinski',
#                  'horse_number': '3',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '2',
#                  'selection_number': 1,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Mr Botanicals',
#                  'horse_number': '3',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '3',
#                  'selection_number': 2,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Class Code',
#                  'horse_number': '2',
#                  'place': 4.6,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '4',
#                  'selection_number': 3,
#                  'show': 14.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 9.4},
#                 {'horse_name': 'Captivating Boy',
#                  'horse_number': '6',
#                  'place': 2.8,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '5',
#                  'selection_number': 4,
#                  'show': 2.8,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Purple Night',
#                  'horse_number': '4',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '6',
#                  'selection_number': 5,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Grit and Curiosity',
#                  'horse_number': '5',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '7',
#                  'selection_number': 6,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': "O'Neill's Legacy",
#                  'horse_number': '9',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '8',
#                  'selection_number': 7,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Shot of a Lifetime',
#                  'horse_number': '9',
#                  'place': 0.0,
#                  'player': 'Michael Alfano',
#                  'player_entry': 1,
#                  'race_number': '9',
#                  'selection_number': 8,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Macho Chrome',
#                  'horse_number': '1',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '2',
#                  'selection_number': 1,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Mr Botanicals',
#                  'horse_number': '3',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '3',
#                  'selection_number': 2,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Dance Lady',
#                  'horse_number': '6',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '4',
#                  'selection_number': 3,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Talk About Autism',
#                  'horse_number': '2',
#                  'place': 3.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '5',
#                  'selection_number': 4,
#                  'show': 10.8,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 7.8},
#                 {'horse_name': 'Irish Song Leader',
#                  'horse_number': '7',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '6',
#                  'selection_number': 5,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Our Expectation',
#                  'horse_number': '8',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '7',
#                  'selection_number': 6,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Zazen',
#                  'horse_number': '3',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '8',
#                  'selection_number': 7,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0},
#                 {'horse_name': 'Sunny Spot',
#                  'horse_number': '5',
#                  'place': 0.0,
#                  'player': 'Greg Altieri',
#                  'player_entry': 1,
#                  'race_number': '9',
#                  'selection_number': 8,
#                  'show': 0.0,
#                  'track_name': 'Golden Gate Fields',
#                  'win': 0.0}],
#  'website': 'horsetourneys'}
# 2023-01-22 15:29:09 [scrapy.core.engine] INFO: Closing spider (finished)
# 2023-01-22 15:29:09 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 353,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 86228,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.271482,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2023, 1, 22, 23, 29, 9, 347168),
#  'item_scraped_count': 1,
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 10,
#  'memusage/max': 99188736,
#  'memusage/startup': 99188736,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2023, 1, 22, 23, 29, 9, 75686)}
# 2023-01-22 15:29:09 [scrapy.core.engine] INFO: Spider closed (finished)
# SUCCESS! Scraping finished. :)
